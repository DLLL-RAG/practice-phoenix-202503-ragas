# %%
# https://docs.arize.com/phoenix/evaluation/evals

# %%
from phoenix.otel import register

tracer_provider = register(
  project_name="default",
  endpoint="http://phoenix:6006/v1/traces",
  # auto_instrument=True # Auto-instrument your app based on installed dependencie
)
# Out:
# 🔭 OpenTelemetry Tracing Details 🔭
# |  Phoenix Project: default
# |  Span Processor: SimpleSpanProcessor
# |  Collector Endpoint: http://phoenix:6006/v1/traces
# |  Transport: HTTP + protobuf
# |  Transport Headers: {}
# |
# |  Using a default SpanProcessor. `add_span_processor` will overwrite this default.
# |
# |  `register` has set this TracerProvider as the global OpenTelemetry default.
# |  To disable this behavior, call `register` with `set_global_tracer_provider=False`.

# %%
from openinference.instrumentation.openai import OpenAIInstrumentor

OpenAIInstrumentor().instrument(tracer_provider=tracer_provider)

# %%
import pandas as pd

# 設定顯示選項，確保不會截斷字串
pd.set_option("display.max_colwidth", None)  # 使得字串欄位完整顯示
pd.set_option("display.max_columns", None)   # 顯示所有欄位
pd.set_option("display.width", None)         # 讓輸出寬度自動調整

# 如果需要顯示更多列，可以視需求調整：
# pd.set_option("display.max_rows", 200)

df = pd.DataFrame(
    [
        {
            "reference": "The Eiffel Tower is located in Paris, France. It was constructed in 1889 as the entrance arch to the 1889 World's Fair.",
            "query": "Where is the Eiffel Tower located?",
            "response": "The Eiffel Tower is located in Paris, France.",
        },
        {
            "reference": "The Great Wall of China is over 13,000 miles long. It was built over many centuries by various Chinese dynasties to protect against nomadic invasions.",
            "query": "How long is the Great Wall of China?",
            "response": "The Great Wall of China is approximately 13,171 miles (21,196 kilometers) long.",
        },
        {
            "reference": "The Amazon rainforest is the largest tropical rainforest in the world. It covers much of northwestern Brazil and extends into Colombia, Peru and other South American countries.",
            "query": "What is the largest tropical rainforest?",
            "response": "The Amazon rainforest is the largest tropical rainforest in the world. It is home to the largest number of plant and animal species in the world.",
        },
        {
            "reference": "Mount Everest is the highest mountain on Earth. It is located in the Mahalangur Himal sub-range of the Himalayas, straddling the border between Nepal and Tibet.",
            "query": "Which is the highest mountain on Earth?",
            "response": "Mount Everest, standing at 29,029 feet (8,848 meters), is the highest mountain on Earth.",
        },
        {
            "reference": "The Nile is the longest river in the world. It flows northward through northeastern Africa for approximately 6,650 km (4,132 miles) from its most distant source in Burundi to the Mediterranean Sea.",
            "query": "What is the longest river in the world?",
            "response": "The Nile River, at 6,650 kilometers (4,132 miles), is the longest river in the world.",
        },
        {
            "reference": "The Mona Lisa was painted by Leonardo da Vinci. It is considered an archetypal masterpiece of the Italian Renaissance and has been described as 'the best known, the most visited, the most written about, the most sung about, the most parodied work of art in the world'.",
            "query": "Who painted the Mona Lisa?",
            "response": "The Mona Lisa was painted by the Italian Renaissance artist Leonardo da Vinci.",
        },
        {
            "reference": "The human body has 206 bones. These bones provide structure, protect organs, anchor muscles, and store calcium.",
            "query": "How many bones are in the human body?",
            "response": "The adult human body typically has 256 bones.",
        },
        {
            "reference": "Jupiter is the largest planet in our solar system. It is a gas giant with a mass more than two and a half times that of all the other planets in the solar system combined.",
            "query": "Which planet is the largest in our solar system?",
            "response": "Jupiter is the largest planet in our solar system.",
        },
        {
            "reference": "William Shakespeare wrote 'Romeo and Juliet'. It is a tragedy about two young star-crossed lovers whose deaths ultimately reconcile their feuding families.",
            "query": "Who wrote 'Romeo and Juliet'?",
            "response": "The play 'Romeo and Juliet' was written by William Shakespeare.",
        },
        {
            "reference": "The first moon landing occurred in 1969. On July 20, 1969, American astronauts Neil Armstrong and Edwin 'Buzz' Aldrin became the first humans to land on the moon as part of the Apollo 11 mission.",
            "query": "When did the first moon landing occur?",
            "response": "The first moon landing took place on July 20, 1969.",
        },
    ]
)
df.head()
# Out:
#                                                                                                                                                                                                reference  \
# 0                                                                                The Eiffel Tower is located in Paris, France. It was constructed in 1889 as the entrance arch to the 1889 World's Fair.
# 1                                                 The Great Wall of China is over 13,000 miles long. It was built over many centuries by various Chinese dynasties to protect against nomadic invasions.
# 2                       The Amazon rainforest is the largest tropical rainforest in the world. It covers much of northwestern Brazil and extends into Colombia, Peru and other South American countries.
# 3                                       Mount Everest is the highest mountain on Earth. It is located in the Mahalangur Himal sub-range of the Himalayas, straddling the border between Nepal and Tibet.
# 4  The Nile is the longest river in the world. It flows northward through northeastern Africa for approximately 6,650 km (4,132 miles) from its most distant source in Burundi to the Mediterranean Sea.
#
#                                       query  \
# 0        Where is the Eiffel Tower located?
# 1      How long is the Great Wall of China?
# 2  What is the largest tropical rainforest?
# 3   Which is the highest mountain on Earth?
# 4   What is the longest river in the world?
#
#                                                                                                                                             response
# 0                                                                                                      The Eiffel Tower is located in Paris, France.
# 1                                                                    The Great Wall of China is approximately 13,171 miles (21,196 kilometers) long.
# 2  The Amazon rainforest is the largest tropical rainforest in the world. It is home to the largest number of plant and animal species in the world.
# 3                                                           Mount Everest, standing at 29,029 feet (8,848 meters), is the highest mountain on Earth.
# 4                                                              The Nile River, at 6,650 kilometers (4,132 miles), is the longest river in the world.

# %%
import nest_asyncio
import openai
import os

from phoenix.evals import HallucinationEvaluator, OpenAIModel, QAEvaluator, run_evals

nest_asyncio.apply()  # This is needed for concurrency in notebook environments

# Set your OpenAI API key
eval_model = OpenAIModel(model="o1", api_key=os.getenv("OPENAI_API_KEY"), base_url=os.getenv("OPENAI_API_BASE"))

# Define your evaluators
hallucination_evaluator = HallucinationEvaluator(eval_model)
qa_evaluator = QAEvaluator(eval_model)

# We have to make some minor changes to our dataframe to use the column names expected by our evaluators
# for `hallucination_evaluator` the input df needs to have columns 'output', 'input', 'context'
# for `qa_evaluator` the input df needs to have columns 'output', 'input', 'reference'
df["context"] = df["reference"]
df.rename(columns={"query": "input", "response": "output"}, inplace=True)
assert all(column in df.columns for column in ["output", "input", "context", "reference"])

# Run the evaluators, each evaluator will return a dataframe with evaluation results
# We upload the evaluation results to Phoenix in the next step
hallucination_eval_df, qa_eval_df = run_evals(
    dataframe=df, evaluators=[hallucination_evaluator, qa_evaluator], provide_explanation=True
)
# Out:
# run_evals |          | 0/20 (0.0%) | ⏳ 00:00<? | ?it/s
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 1: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 2: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 3: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 4: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 5: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 6: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 7: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 9: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 9: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 8: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 9: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 9: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 9: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 9: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 10: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 10: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 9: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 10: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 9: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 10: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Exception in worker on attempt 10: raised InternalServerError("Error code: 500 - {'error': 'An error occurred while processing the request.'}")
# Requeuing...
# Retries exhausted after 11 attempts: Error code: 500 - {'error': 'An error occurred while processing the request.'}
# Retries exhausted after 11 attempts: Error code: 500 - {'error': 'An error occurred while processing the request.'}

# %%
import pandas as pd

results_df = df.copy()
results_df["hallucination_eval"] = hallucination_eval_df["label"]
results_df["hallucination_explanation"] = hallucination_eval_df["explanation"]
results_df["qa_eval"] = qa_eval_df["label"]
results_df["qa_explanation"] = qa_eval_df["explanation"]

# 顯示前 5 筆資料，並確保欄位內容不被截斷
results_df.head()
# Out:
#                                                                                                                                                                                                reference  \
# 0                                                                                The Eiffel Tower is located in Paris, France. It was constructed in 1889 as the entrance arch to the 1889 World's Fair.
# 1                                                 The Great Wall of China is over 13,000 miles long. It was built over many centuries by various Chinese dynasties to protect against nomadic invasions.
# 2                       The Amazon rainforest is the largest tropical rainforest in the world. It covers much of northwestern Brazil and extends into Colombia, Peru and other South American countries.
# 3                                       Mount Everest is the highest mountain on Earth. It is located in the Mahalangur Himal sub-range of the Himalayas, straddling the border between Nepal and Tibet.
# 4  The Nile is the longest river in the world. It flows northward through northeastern Africa for approximately 6,650 km (4,132 miles) from its most distant source in Burundi to the Mediterranean Sea.
#
#                                       input  \
# 0        Where is the Eiffel Tower located?
# 1      How long is the Great Wall of China?
# 2  What is the largest tropical rainforest?
# 3   Which is the highest mountain on Earth?
# 4   What is the longest river in the world?
#
#                                                                                                                                               output  \
# 0                                                                                                      The Eiffel Tower is located in Paris, France.
# 1                                                                    The Great Wall of China is approximately 13,171 miles (21,196 kilometers) long.
# 2  The Amazon rainforest is the largest tropical rainforest in the world. It is home to the largest number of plant and animal species in the world.
# 3                                                           Mount Everest, standing at 29,029 feet (8,848 meters), is the highest mountain on Earth.
# 4                                                              The Nile River, at 6,650 kilometers (4,132 miles), is the longest river in the world.
#
#                                                                                                                                                                                                  context  \
# 0                                                                                The Eiffel Tower is located in Paris, France. It was constructed in 1889 as the entrance arch to the 1889 World's Fair.
# 1                                                 The Great Wall of China is over 13,000 miles long. It was built over many centuries by various Chinese dynasties to protect against nomadic invasions.
# 2                       The Amazon rainforest is the largest tropical rainforest in the world. It covers much of northwestern Brazil and extends into Colombia, Peru and other South American countries.
# 3                                       Mount Everest is the highest mountain on Earth. It is located in the Mahalangur Himal sub-range of the Himalayas, straddling the border between Nepal and Tibet.
# 4  The Nile is the longest river in the world. It flows northward through northeastern Africa for approximately 6,650 km (4,132 miles) from its most distant source in Burundi to the Mediterranean Sea.
#
#   hallucination_eval  \
# 0            factual
# 1       hallucinated
# 2       hallucinated
# 3               None
# 4               None
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       hallucination_explanation  \
# 0                                                                                                                                                                                                                                                                                                                                               The query asks for the location of the Eiffel Tower. The reference text states that the Eiffel Tower is located in Paris, France. The answer states the same. Therefore, the answer is factual.\nLABEL: factual
# 1                                                                                               The query asks about the length of the Great Wall of China. The reference text states that the Great Wall is over 13,000 miles long. The answer states that the Great Wall is approximately 13,171 miles long. This is close to the information in the reference text, but provides a specific number that is not present in the reference text. While the length might be accurate, it is not directly supported by the reference text.\n\nLABEL: hallucinated
# 2  The query asks for the largest tropical rainforest.\nThe reference text states that the Amazon rainforest is the largest tropical rainforest in the world.\nThe answer states that the Amazon rainforest is the largest tropical rainforest in the world and that it is home to the largest number of plant and animal species in the world.\nThe reference text does not mention that the Amazon rainforest is home to the largest number of plant and animal species in the world.\nTherefore, the answer contains a hallucination.\n\nLABEL: hallucinated
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          None
#
#    qa_eval  \
# 0  correct
# 1  correct
# 2  correct
# 3  correct
# 4  correct
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 qa_explanation
# 0                                                                                                                                                                                                                                                                        The question asks for the location of the Eiffel Tower. The reference text states the Eiffel Tower is located in Paris, France. The answer states the Eiffel Tower is located in Paris, France. Therefore, the answer correctly answers the question.\nLABEL: correct
# 1                                                                                                                                                                                                                                          The question asks for the length of the Great Wall of China.\nThe reference states that the Great Wall of China is over 13,000 miles long.\nThe answer states that the Great Wall of China is approximately 13,171 miles long.\nThe answer is consistent with the reference text.\n\nLABEL: correct
# 2  The question asks "What is the largest tropical rainforest?".\nThe reference text states "The Amazon rainforest is the largest tropical rainforest in the world."\nThe answer states "The Amazon rainforest is the largest tropical rainforest in the world. It is home to the largest number of plant and animal species in the world."\nThe first sentence of the answer correctly answers the question. The second sentence provides additional information that is not relevant to the question but is not incorrect.\n\nLABEL: correct
# 3                                                                                                                                                                                                                                     The question asks for the highest mountain on Earth.\nThe reference states that Mount Everest is the highest mountain on Earth.\nThe answer states that Mount Everest is the highest mountain on Earth and provides its height.\nThe answer is correct and fully answers the question.\n\nLABEL: correct
# 4                                                                                 The question asks for the longest river in the world.\nThe reference text states "The Nile is the longest river in the world." and provides its length.\nThe answer states "The Nile River, at 6,650 kilometers (4,132 miles), is the longest river in the world."\nThe answer correctly identifies the Nile as the longest river and includes its length, which is consistent with the reference text.\nTherefore, the answer is correct.\n\nLABEL: correct
